# %% [markdown]
# # 3 — Modelling (Training & Evaluation)
#
# Tahap modelling: split train/test, pelatihan model, dan evaluasi metrik.
#
# **Input:** `2_data_preprocessing/output/2.2_final_feature_set.csv`
#
# **Output:**
# - `3_modelling/output/model_metrics.csv`
# - `3_modelling/output/3_model_predictions.csv`
# - `3_modelling/output/top_15_feature_importance.csv`

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Coba gunakan XGBoost; jika tidak tersedia, fallback ke RandomForest agar notebook tetap runnable.
try:
    import xgboost as xgb
    use_xgboost = True
    model_name = 'XGBoost'
except ImportError:
    from sklearn.ensemble import RandomForestRegressor
    use_xgboost = False
    model_name = 'RandomForest'

def find_project_root(start: Path) -> Path:
    start = start.resolve()
    for p in [start, *start.parents]:
        if (p / '2_data_preprocessing' / 'output' / '2.2_final_feature_set.csv').exists():
            return p
    raise FileNotFoundError('Could not find 2.2_final_feature_set.csv in current or parent directories.')

ROOT = find_project_root(Path.cwd())
input_path = ROOT / '2_data_preprocessing' / 'output' / '2.2_final_feature_set.csv'
output_dir = ROOT / '3_modelling' / 'output'
output_dir.mkdir(parents=True, exist_ok=True)
metrics_path = output_dir / 'model_metrics.csv'
pred_path = output_dir / '3_model_predictions.csv'

df = pd.read_csv(input_path)
df['tanggal'] = pd.to_datetime(df['tanggal'])
df = df.sort_values(by=['provinsi_id', 'tanggal']).reset_index(drop=True)

print(f'Loaded: {input_path}')
print(f'Shape: {df.shape[0]:,} rows × {df.shape[1]} cols')
# Out:
# Loaded: C:\Users\Unpad-hci\Microsoft-Datathon-TWP90-Early-Warning-System\2_data_preprocessing\output\2.2_final_feature_set.csv
# Shape: 1,488 rows × 36 cols

# %%
# Siapkan data modelling: minimal harus punya target dan fitur lag
lag_columns = [col for col in df.columns if '_lag_' in col]
required_cols = lag_columns + ['twp90_pct']
df_model = df.dropna(subset=required_cols).copy()

# Pastikan tahun numeric
df_model['tahun'] = pd.to_numeric(df_model['tahun'], errors='coerce')
df_model = df_model.dropna(subset=['tahun'])
df_model['tahun'] = df_model['tahun'].astype(int)

kolom_non_prediktor = ['provinsi_id', 'nama_provinsi', 'tanggal', 'tahun', 'bulan', 'twp90_pct']
X_cols = [col for col in df_model.columns if col not in kolom_non_prediktor]
print(f'Fitur kandidat untuk modelling: {X_cols}')

print(f'Total rows available for modelling: {len(df_model):,}')
print(f'Total features used: {len(X_cols)}')

# Split temporal: Train 2022-2024 | Test 2025
train_data = df_model[df_model['tahun'] <= 2024].copy()
test_data = df_model[df_model['tahun'] == 2025].copy()

if train_data.empty or test_data.empty:
    print('Warning: strict temporal split produced an empty set. Using 80/20 chronological fallback split.')
    df_model = df_model.sort_values('tanggal').reset_index(drop=True)
    split_idx = int(0.8 * len(df_model))
    train_data = df_model.iloc[:split_idx].copy()
    test_data = df_model.iloc[split_idx:].copy()

X_train = train_data[X_cols]
y_train = train_data['twp90_pct']
X_test = test_data[X_cols]
y_test = test_data['twp90_pct']

print(f'Dimensi X_train: {X_train.shape}')
print(f'Dimensi X_test: {X_test.shape}')

assert not X_train.empty and not X_test.empty, 'Dataset train/test kosong setelah preprocessing.'
assert (df_model['provinsi_id'] == 19).sum() == 0, 'provinsi_id 19 still present (expected removed upstream).'
# Out:
# Fitur kandidat untuk modelling: ['x1_bi_rate_pct', 'x2_inflasi_yoy', 'x3_pdrb_per_kapita', 'x4_tpt_pct', 'x5_penetrasi_internet_pct', 'x6_tabungan_miliar', 'x7_jumlah_kc_bank', 'x8_ldr_pct', 'x9_npl_ratio', 'x10_rasio_umkm', 'x1_bi_rate_pct_lag_3', 'x2_inflasi_yoy_lag_3', 'x3_pdrb_per_kapita_lag_3', 'x4_tpt_pct_lag_3', 'x5_penetrasi_internet_pct_lag_3', 'x6_tabungan_miliar_lag_3', 'x7_jumlah_kc_bank_lag_3', 'x8_ldr_pct_lag_3', 'x9_npl_ratio_lag_3', 'x10_rasio_umkm_lag_3', 'x1_bi_rate_pct_lag_6', 'x2_inflasi_yoy_lag_6', 'x3_pdrb_per_kapita_lag_6', 'x4_tpt_pct_lag_6', 'x5_penetrasi_internet_pct_lag_6', 'x6_tabungan_miliar_lag_6', 'x7_jumlah_kc_bank_lag_6', 'x8_ldr_pct_lag_6', 'x9_npl_ratio_lag_6', 'x10_rasio_umkm_lag_6']
# Total rows available for modelling: 1,302
# Total features used: 30
# Dimensi X_train: (930, 30)
# Dimensi X_test: (372, 30)

# %%
# Latih model baseline
if use_xgboost:
    model = xgb.XGBRegressor(
        objective='reg:squarederror',
        n_estimators=200,
        learning_rate=0.05,
        max_depth=6,
        random_state=42,
    )
else:
    model = RandomForestRegressor(n_estimators=300, random_state=42, n_jobs=-1)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

rmse = float(np.sqrt(mean_squared_error(y_test, y_pred)))
mae = float(mean_absolute_error(y_test, y_pred))
r2 = float(r2_score(y_test, y_pred))

print(f'--- Evaluasi Baseline Model ({model_name}) ---')
print(f'RMSE: {rmse:.4f}')
print(f'MAE: {mae:.4f}')
print(f'R2: {r2:.4f}')

metrics_df = pd.DataFrame([{
    'model': model_name,
    'rmse': rmse,
    'mae': mae,
    'r2': r2,
    'n_train': int(len(X_train)),
    'n_test': int(len(X_test)),
    'n_features': int(len(X_cols)),
}])
metrics_df.to_csv(metrics_path, index=False)
print(f'Saved: {metrics_path}')

out_cols = [c for c in ['provinsi_id', 'nama_provinsi', 'tanggal', 'tahun', 'bulan', 'twp90_pct'] if c in test_data.columns]
pred_df = test_data[out_cols].copy()
pred_df = pred_df.rename(columns={'twp90_pct': 'y_true'})
pred_df['y_pred'] = y_pred
pred_df['error'] = pred_df['y_pred'] - pred_df['y_true']
pred_df.to_csv(pred_path, index=False)
print(f'Saved: {pred_path}')
# Out:
# --- Evaluasi Baseline Model (XGBoost) ---
# RMSE: 0.0086
# MAE: 0.0044
# R2: 0.3704
# Saved: C:\Users\Unpad-hci\Microsoft-Datathon-TWP90-Early-Warning-System\3_modelling\output\model_metrics.csv
# Saved: C:\Users\Unpad-hci\Microsoft-Datathon-TWP90-Early-Warning-System\3_modelling\output\3_model_predictions.csv

# %%
# Hitung Feature Importance dan ambil 15 fitur terbaik (Tanpa Redundansi Lag)
if not hasattr(model, 'feature_importances_'):
    raise AttributeError(f"Model {type(model).__name__} tidak memiliki attribute feature_importances_.")

importances = np.asarray(model.feature_importances_, dtype=float)
if importances.shape[0] != len(X_cols):
    raise ValueError(
        f"Panjang feature_importances_ ({importances.shape[0]}) tidak sama dengan jumlah fitur ({len(X_cols)})."
    )

fi_df = pd.DataFrame({'feature': X_cols, 'importance': importances})
fi_df = fi_df.sort_values('importance', ascending=False).reset_index(drop=True)

# Ekstrak identitas fitur (misal: 'x7_jumlah_kc_bank_lag_6' menjadi 'x7') untuk menghilangkan redundansi
fi_df['feature_base'] = fi_df['feature'].str.extract(r'(x\d+)')
# Hapus duplikat berdasarkan feature_base, simpan yang pertama (karena sudah disortir, maka importance tertinggi yang tersimpan)
fi_df = fi_df.drop_duplicates(subset='feature_base').reset_index(drop=True)

fi_df['rank'] = np.arange(1, len(fi_df) + 1)

total_imp = float(fi_df['importance'].sum())
fi_df['importance_pct'] = (fi_df['importance'] / total_imp) if total_imp > 0 else 0.0

# Ambil 15 fitur unik terbaik
top15_df = fi_df.head(15).copy()
top15_df.insert(0, 'model', model_name)

# Hapus kolom pembantu sebelum simpan
top15_df = top15_df.drop(columns=['feature_base'])

fi_path = output_dir / 'top_15_feature_importance.csv'
top15_df.to_csv(fi_path, index=False)

print(f'Saved: {fi_path}')
print(top15_df)
# Out:
# Saved: C:\Users\Unpad-hci\Microsoft-Datathon-TWP90-Early-Warning-System\3_modelling\output\top_15_feature_importance_unique.csv
#      model                          feature  importance  rank  importance_pct
# 0  XGBoost          x7_jumlah_kc_bank_lag_6    0.312520     1        0.404332
# 1  XGBoost               x6_tabungan_miliar    0.169179     2        0.218880
# 2  XGBoost               x3_pdrb_per_kapita    0.125471     3        0.162332
# 3  XGBoost             x10_rasio_umkm_lag_3    0.055292     4        0.071536
# 4  XGBoost                     x9_npl_ratio    0.045304     5        0.058614
# 5  XGBoost                   x1_bi_rate_pct    0.024997     6        0.032341
# 6  XGBoost                 x4_tpt_pct_lag_3    0.015647     7        0.020244
# 7  XGBoost  x5_penetrasi_internet_pct_lag_3    0.014093     8        0.018234
# 8  XGBoost                 x8_ldr_pct_lag_6    0.007742     9        0.010017
# 9  XGBoost             x2_inflasi_yoy_lag_6    0.002681    10        0.003469
